# %%
import pandas as pd

# %%
file_path = 'data.csv'

# %%
df = pd.read_csv(file_path, header=0, index_col=0)

# %%
df.head()
# Out:
#            wanderSpeed  wanderSlope  wanderRoundness  \
# Emotion 1          100            0              1.0
# Emotion 2           35            0              0.5
# Emotion 3          100            0              0.0
# Emotion 4           40            0              0.0
#
#            wanderTurnToForwardRatio  wanderCycleRate  \
# Emotion 1                       0.8              0.5
# Emotion 2                       0.8              0.5
# Emotion 3                       0.8              5.0
# Emotion 4                       0.8              6.0
#
#            wanderCycleStandardDeviation  wanderSpeedStandardDeviation  \
# Emotion 1                           0.5                             0
# Emotion 2                           0.2                             0
# Emotion 3                           1.0                             0
# Emotion 4                           0.1                            10
#
#            wanderPhase  blinkTemperature  blinkSlope  ...  \
# ...

# %%
df.describe()
# Out:
#        wanderSpeed  wanderSlope  wanderRoundness  wanderTurnToForwardRatio  \
# count     4.000000          4.0         4.000000                       4.0
# mean     68.750000          0.0         0.375000                       0.8
# std      36.142081          0.0         0.478714                       0.0
# min      35.000000          0.0         0.000000                       0.8
# 25%      38.750000          0.0         0.000000                       0.8
# 50%      70.000000          0.0         0.250000                       0.8
# 75%     100.000000          0.0         0.625000                       0.8
# max     100.000000          0.0         1.000000                       0.8
#
#        wanderCycleRate  wanderCycleStandardDeviation  \
# count         4.000000                      4.000000
# mean          3.000000                      0.450000
# std           2.915476                      0.404145
# min           0.500000                      0.100000
# ...

# %%
df.cov()
# Out:
#                                     wanderSpeed  wanderSlope  wanderRoundness  \
# wanderSpeed                         1306.250000          0.0         4.791667
# wanderSlope                            0.000000          0.0         0.000000
# wanderRoundness                        4.791667          0.0         0.229167
# wanderTurnToForwardRatio               0.000000          0.0         0.000000
# wanderCycleRate                       -5.833333          0.0        -1.250000
# wanderCycleStandardDeviation          12.416667          0.0        -0.025000
# wanderSpeedStandardDeviation         -95.833333          0.0        -1.250000
# wanderPhase                            0.000000          0.0         0.000000
# blinkTemperature                      12.750000          0.0        -0.058333
# blinkSlope                            31.250000          0.0        -0.041667
# blinkLightsOnToOffRatio                4.062500          0.0        -0.035417
# ...
