# %%
import numpy as np
from scipy.stats import qmc

# %%
# Define the number of variables and samples
n_vars = 9
n_samples = 2**9

# %%
# Initialize the Sobol sequence generator
sobol_sampler = qmc.Sobol(d=n_vars, scramble=True)

# Initialize the Latin Hypercube Sampler
lhs_sampler = qmc.LatinHypercube(d=n_vars)

# %%
# Generate samples
sobol_samples = sobol_sampler.random(n=n_samples)
lhs_samples = lhs_sampler.random(n=n_samples)

# %%
# Scale samples to the desired range
l_bounds = [20, 0, 0.5, 
            0, -1, 0.5, 
            100, -1, 0.5]
u_bounds = [100, 1, 6, 
            1, 1, 6,
            1000, 1, 6]

sobol_samples_scaled = qmc.scale(sobol_samples, l_bounds, u_bounds)
lhs_samples_scaled = qmc.scale(lhs_samples, l_bounds, u_bounds)

# %%
import pandas as pd

# %%
column_names = np.array(["wanderSpeed", "wanderRoundness", "wanderCycleRate", 
                "blinkTemperature", "blinkSlope", "blinkCycleRate", 
                "beepPitch", "beepSlope", "beepCycleRate"])

# %%
df_sobol = pd.DataFrame(data=sobol_samples_scaled, columns=column_names)

# %%
df_sobol.beepSlope = round(df_sobol.beepSlope)
df_sobol.blinkSlope = round(df_sobol.blinkSlope)

# %%
df_sobol.head(20)
# Out:
#     wanderSpeed  wanderRoundness  wanderCycleRate  blinkTemperature  \
# 0     31.249670         0.885147         3.694287          0.672526
# 1     99.234700         0.289483         1.497651          0.125355
# 2     63.126953         0.535270         5.353269          0.879959
# 3     46.390621         0.130921         2.458402          0.427626
# 4     53.870449         0.669726         0.706578          0.341471
# 5     75.644568         0.015385         4.353744          0.856800
# 6     81.753613         0.753612         3.182001          0.101639
# 7     28.728202         0.407956         4.755915          0.586806
# 8     22.767302         0.579460         2.679003          0.798836
# 9     87.080472         0.237624         5.305650          0.252893
# 10    70.357485         0.999147         0.846776          0.507566
# 11    59.793023         0.340995         4.171676          0.053989
# 12    42.275312         0.866155         5.835869          0.217780
# 13    67.877523         0.457996         1.931236          0.734338
# 14    94.601807         0.711483         3.531015          0.479245
# 15    35.248294         0.119639         1.699614          0.963169
# 16    37.552454         0.719514         5.121110          0.071648
# 17    91.982821         0.065208         2.859685          0.618811
# 18    65.572334         0.826866         3.988465          0.371950
# 19    44.890675         0.481185         1.028809          0.824307
#
#     blinkSlope  blinkCycleRate   beepPitch  beepSlope  beepCycleRate
# 0          1.0        2.074054  765.625146        1.0       1.218910
# 1         -0.0        5.075924  295.477020       -0.0       4.052034
# 2         -1.0        3.669453  786.561644       -1.0       5.816460
# 3          0.0        0.805552  358.488531        0.0       2.978086
# 4          0.0        2.967534  957.950671       -1.0       5.260448
# 5         -1.0        5.643235  545.679519        0.0       2.426984
# 6         -0.0        4.112055  585.467979        1.0       0.748455
# 7          1.0        1.652203  102.991674       -0.0       3.587244
# 8         -0.0        1.016068  935.215499       -1.0       4.947160
# 9          1.0        3.373163  463.398697        0.0       2.108330
# 10         0.0        4.684130  618.749837        1.0       1.036939
# 11        -1.0        2.551613  188.788308       -0.0       3.870278
# 12        -1.0        1.265100  679.389696        1.0       1.576505
# 13         0.0        4.584921  261.755930       -0.0       4.415005
# 14         1.0        5.857116  869.281711       -1.0       5.400491
# 15        -0.0        2.667878  381.662505        0.0       2.567411
# 16         0.0        4.329206  319.709772       -1.0       1.931996
# 17        -1.0        1.520989  735.252496        0.0       4.765141
# 18        -0.0        2.755753  326.352463        1.0       3.693483
# 19         1.0        5.769079  812.532924       -0.0       0.855047

# %%
df_sobol.cov().round()
# Out:
#                   wanderSpeed  wanderRoundness  wanderCycleRate  \
# wanderSpeed             534.0              0.0              0.0
# wanderRoundness           0.0              0.0             -0.0
# wanderCycleRate           0.0             -0.0              3.0
# blinkTemperature          0.0             -0.0             -0.0
# blinkSlope                0.0              0.0              0.0
# blinkCycleRate            0.0             -0.0              0.0
# beepPitch                 0.0              0.0              0.0
# beepSlope                -1.0              0.0              0.0
# beepCycleRate            -0.0             -0.0             -0.0
#
#                   blinkTemperature  blinkSlope  blinkCycleRate  beepPitch  \
# wanderSpeed                    0.0         0.0             0.0        0.0
# wanderRoundness               -0.0         0.0            -0.0        0.0
# wanderCycleRate               -0.0         0.0             0.0        0.0
# blinkTemperature               0.0         0.0             0.0        0.0
# blinkSlope                     0.0         1.0             0.0        0.0
# blinkCycleRate                 0.0         0.0             3.0        0.0
# beepPitch                      0.0         0.0             0.0    67632.0
# beepSlope                      0.0         0.0             0.0        0.0
# beepCycleRate                 -0.0         0.0            -0.0        0.0
#
#                   beepSlope  beepCycleRate
# wanderSpeed            -1.0           -0.0
# wanderRoundness         0.0           -0.0
# wanderCycleRate         0.0           -0.0
# blinkTemperature        0.0           -0.0
# blinkSlope              0.0            0.0
# blinkCycleRate          0.0           -0.0
# beepPitch               0.0            0.0
# beepSlope               1.0            0.0
# beepCycleRate           0.0            3.0

# %%
df_sobol.to_csv("input_data.csv", sep=',', header=False, index=False)

# %%
df_lhs = pd.DataFrame(data=lhs_samples_scaled, columns=column_names)

# %%
df_lhs.head(20)
# Out:
#     wanderSpeed  wanderRoundness  wanderCycleRate  blinkTemperature  \
# 0     34.323926         0.462454         5.206247          0.065366
# 1     85.629218         0.818691         1.247614          0.390414
# 2     77.861647         0.763759         4.948575          0.844407
# 3     56.199145         0.300531         1.949184          0.969754
# 4     58.844310         0.055448         2.959289          0.789994
# 5     87.802453         0.998800         4.005076          0.781815
# 6     64.727367         0.302812         4.514163          0.533441
# 7     40.883372         0.549499         2.794160          0.911855
# 8     23.682346         0.994436         3.067369          0.459114
# 9     31.020210         0.754129         2.661493          0.293818
# 10    68.595554         0.852163         1.363079          0.229822
# 11    56.735119         0.545266         3.328541          0.123978
# 12    45.062243         0.433421         5.363443          0.099856
# 13    44.450672         0.115911         5.487694          0.758491
# 14    62.277678         0.649522         3.368874          0.035537
# 15    83.376441         0.488548         3.919135          0.044765
# 16    38.314101         0.783444         2.410340          0.637725
# 17    47.853502         0.528574         2.448503          0.348951
# 18    93.556506         0.338178         1.843536          0.245204
# 19    98.931073         0.908521         2.245634          0.208571
#
#     blinkSlope  blinkCycleRate   beepPitch  beepSlope  beepCycleRate
# 0    -0.089942        2.502708  751.931613   0.446463       1.259724
# 1    -0.328796        1.462702  344.444751   0.753758       3.600844
# 2    -0.759807        3.328743  824.584167   0.925561       5.562967
# 3    -0.754429        4.401734  762.341350   0.576081       4.175087
# 4     0.038058        5.384076  851.812791  -0.830060       2.571146
# 5     0.478498        4.715135  128.318083  -0.070793       2.510409
# 6     0.338921        2.141655  597.873254   0.807001       1.237512
# 7    -0.056337        4.528174  304.407368   0.026301       2.869730
# 8    -0.875637        4.586556  943.660592   0.735347       5.843671
# 9    -0.422611        0.967692  816.959928   0.021666       4.973105
# 10   -0.127060        3.679930  121.373251   0.439223       2.805700
# 11    0.433027        3.650504  547.954083  -0.231466       1.150057
# 12    0.170449        1.414370  506.410110   0.532191       1.477159
# 13    0.968256        1.236146  635.978507  -0.726772       2.785167
# 14   -0.208052        4.247663  348.489977  -0.683733       3.573102
# 15   -0.245925        5.394702  866.330742   0.777667       4.820663
# 16   -0.416880        3.451334  277.320166   0.078199       2.010298
# 17    0.940404        5.323279  600.528967  -0.031224       1.339059
# 18   -0.569793        3.659896  536.010826   0.658870       1.564542
# 19    0.954512        3.625210  774.218418  -0.496441       1.492742

# %%
df_lhs.cov().round()
# Out:
#                   wanderSpeed  wanderRoundness  wanderCycleRate  \
# wanderSpeed             534.0              0.0             -1.0
# wanderRoundness           0.0              0.0             -0.0
# wanderCycleRate          -1.0             -0.0              3.0
# blinkTemperature         -0.0             -0.0              0.0
# blinkSlope                1.0             -0.0              0.0
# blinkCycleRate            3.0              0.0              0.0
# beepPitch               320.0              2.0            -15.0
# beepSlope                -0.0              0.0              0.0
# beepCycleRate             1.0             -0.0             -0.0
#
#                   blinkTemperature  blinkSlope  blinkCycleRate  beepPitch  \
# wanderSpeed                   -0.0         1.0             3.0      320.0
# wanderRoundness               -0.0        -0.0             0.0        2.0
# wanderCycleRate                0.0         0.0             0.0      -15.0
# blinkTemperature               0.0        -0.0             0.0        3.0
# blinkSlope                    -0.0         0.0            -0.0        0.0
# blinkCycleRate                 0.0        -0.0             3.0       29.0
# beepPitch                      3.0         0.0            29.0    67657.0
# beepSlope                     -0.0        -0.0            -0.0       -2.0
# beepCycleRate                  0.0        -0.0            -0.0      -17.0
#
#                   beepSlope  beepCycleRate
# wanderSpeed            -0.0            1.0
# wanderRoundness         0.0           -0.0
# wanderCycleRate         0.0           -0.0
# blinkTemperature       -0.0            0.0
# blinkSlope             -0.0           -0.0
# blinkCycleRate         -0.0           -0.0
# beepPitch              -2.0          -17.0
# beepSlope               0.0            0.0
# beepCycleRate           0.0            3.0

# %%
# Open the CSV file for reading
with open('input_data.csv', 'r') as input_file:
    # Open the output file for writing
    with open('output.txt', 'w') as output_file:
        # Loop through each line in the CSV file
        for line_number, line in enumerate(input_file, start=1):
            # Split the line into individual values
            values = line.strip().split(',')
            
            # Write the values to the output file in the desired format
            output_file.write(f'wanderSpeed = {values[0]};\n')
            output_file.write(f'wanderRoundness = {values[1]};\n')
            output_file.write(f'wanderCycleRate = {values[2]};\n')
            output_file.write(f'blinkTemperature = {values[3]};\n')
            output_file.write(f'blinkSlope = {values[4]};\n')
            output_file.write(f'blinkCycleRate = {values[5]};\n')
            output_file.write(f'beepPitch = {values[6]};\n')
            output_file.write(f'beepSlope = {values[7]};\n')
            output_file.write(f'beepCycleRate = {values[8]};\n\n')
            
            # Write the function calls using the values
            output_file.write(f'WanderBlinkBeep(duration, stayInBounds,\n')
            output_file.write(f'                wanderSpeed, wanderSlope, wanderRoundness, wanderCycleRate, wanderCycleStandardDeviation, wanderSpeedStandardDeviation, wanderPhase,\n')
            output_file.write(f'                blinkTemperature, blinkSlope, blinkLightsOnToOffRatio, blinkCycleRate, blinkCycleStandardDeviation, blinkTemperatureStandardDeviation, blinkPhase,\n')
            output_file.write(f'                0, 0, 0, 0, 0, 0, 0, 0);\n\n')
            
            output_file.write(f'WanderBlinkBeep(duration, stayInBounds,\n')
            output_file.write(f'                0, 0, 0, 0, 0, 0, 0,\n')
            output_file.write(f'                0, 0, 0, 0, 0, 0, 0,\n')
            output_file.write(f'                beepPitch, beepSlope,beepSoundToSilenceRatio, beepCycleRate, beepCycleStandardDeviation, beepPitchStandardDeviation, beepRandomSoundProbability, beepPhase);\n\n')
