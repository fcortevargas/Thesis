# %%
from pandasql import sqldf
import pandas as pd

# %%
# Read the CSV file into a DataFrame
file_path = '../Data/Processed/rating.csv'
rating_df = pd.read_csv(file_path, header=0, index_col=[0, 3])

# %%
rating_df
# Out:
#                                       start_time       end_time  joy  sadness  \
# participant_id           video_id
# 5c791e24266f210012af518d 1          5/1/24 21:30   5/1/24 21:46  NaN      1.0
#                          6          5/1/24 21:30   5/1/24 21:46  NaN      4.0
#                          59         5/1/24 21:30   5/1/24 21:46  NaN      5.0
#                          61         5/1/24 21:30   5/1/24 21:46  NaN      1.0
#                          219        5/1/24 21:30   5/1/24 21:46  NaN      NaN
# ...                                          ...            ...  ...      ...
# 62a447d91e71bfacd2e8c006 298       5/11/24 14:44  5/11/24 15:19  NaN      5.0
#                          409       5/11/24 14:44  5/11/24 15:19  NaN      4.0
#                          438       5/11/24 14:44  5/11/24 15:19  4.0      NaN
#                          499       5/11/24 14:44  5/11/24 15:19  NaN      NaN
#                          509       5/11/24 14:44  5/11/24 15:19  NaN      5.0
#
#                                    fear  anger  disgust  surprise  other  \
# participant_id           video_id
# 5c791e24266f210012af518d 1          1.0    NaN      NaN       2.0    NaN
#                          6          NaN    NaN      NaN       NaN    NaN
#                          59         1.0    NaN      NaN       NaN    NaN
#                          61         NaN    1.0      1.0       NaN    NaN
#                          219        4.0    NaN      NaN       1.0    NaN
# ...                                 ...    ...      ...       ...    ...
# 62a447d91e71bfacd2e8c006 298        NaN    NaN      NaN       NaN    NaN
#                          409        NaN    NaN      NaN       NaN    NaN
#                          438        NaN    NaN      NaN       NaN    NaN
#                          499        4.0    NaN      NaN       3.0    NaN
#                          509        NaN    NaN      NaN       NaN    NaN
#
#                                   other_text  pleasure  arousal  dominance  \
# participant_id           video_id
# 5c791e24266f210012af518d 1               NaN         4        3          3
#                          6               NaN         1        1          2
#                          59              NaN         1        1          1
#                          61              NaN         4        3          3
#                          219             NaN         2        7          4
# ...                                      ...       ...      ...        ...
# 62a447d91e71bfacd2e8c006 298             NaN         1        6          2
#                          409             NaN         1        8          5
#                          438             NaN         7        7          6
#                          499             NaN         3        8          5
#                          509             NaN         1        6          3
#
#                                                                            appraisal
# participant_id           video_id
# 5c791e24266f210012af518d 1                       i honestly dont know about this one
#                          6         it seemed like something had made the robot sa...
#                          59        it seems to be sad and maybe a little confused...
#                          61                 it seemed to be kinda all over the place
#                          219       it seems like something made the robot scared,...
# ...                                                                              ...
# 62a447d91e71bfacd2e8c006 298       Robot was very sad, and just bumbling about, w...
#                          409       It was sad and was singing a sad song - it was...
#                          438       Robot seemed quite happy, and was going about ...
#                          499                   Robot was agitated, probably fearful.
#                          509       Robot seemed sad and worried.  I think somethi...
#
# [3160 rows x 14 columns]

# %%
# Read the CSV file into a DataFrame
file_path = '../Data/Processed/video.csv'
video_df = pd.read_csv(file_path, header=0, index_col=[9])

# %%
video_df
# Out:
#           wanderSpeed  wanderRoundness  wanderCycleRate  blinkTemperature  \
# video_id
# 1           87.236897         0.000103         4.757621          0.167687
# 2           39.856034         0.627384         3.082747          0.831775
# 3           52.935385         0.260046         3.387107          0.456451
# 4           75.588838         0.882944         1.713439          0.542408
# 5           69.660266         0.453108         2.234201          0.660778
# ...               ...              ...              ...               ...
# 508         69.789832         0.827974         1.541092          0.084773
# 509         75.449241         0.257818         2.406045          0.211918
# 510         52.814612         0.885172         5.455919          0.782272
# 511         39.985751         0.002274         1.036630          0.408023
# 512         87.385175         0.625214         4.085298          0.587746
#
#           blinkSlope  blinkCycleRate   beepPitch  beepSlope  beepCycleRate
# video_id
# 1               -1.0        5.502769  378.842406       -1.0       5.141918
# 2                0.0        2.096989  906.623426        0.0       1.415101
# 3                1.0        0.703502  215.861748        1.0       1.976169
# 4               -0.0        4.194543  588.079762       -0.0       4.413018
# 5               -0.0        4.945740  153.151721        1.0       2.735729
# ...              ...             ...         ...        ...            ...
# 508             -1.0        0.714256  614.235116        0.0       2.335331
# 509             -1.0        2.839445  182.836297       -1.0       3.494309
# 510              0.0        4.935008  766.868250        0.0       3.116435
# 511              1.0        3.534671  522.473252        1.0       1.013360
# 512             -0.0        1.527055  838.442265       -0.0       5.429523
#
# [512 rows x 9 columns]

# %%
video_rating_df = sqldf('''
                        SELECT
                            rating_df.participant_id,
                            rating_df.video_id,
                            rating_df.start_time,
                            rating_df.end_time,
                            video_df.wanderSpeed AS wander_speed,
                            video_df.wanderRoundness AS wander_roundness,
                            video_df.wanderRoundness / video_df.wanderCycleRate as wander_roundness_effective,
                            video_df.wanderCycleRate AS wander_cycle_rate, 
                            video_df.blinkTemperature AS blink_temperature,
                            video_df.blinkSlope AS blink_slope,
                            video_df.blinkCycleRate AS blink_cycle_rate,
                            video_df.beepPitch AS beep_pitch,
                            video_df.beepSlope AS beep_slope,
                            video_df.beepCycleRate AS beep_cycle_rate,
                            rating_df.joy AS joy_intensity,
                            rating_df.sadness AS sadness_intensity,
                            rating_df.fear AS fear_intensity,
                            rating_df.anger AS anger_intensity,
                            rating_df.disgust AS disgust_intensity,
                            rating_df.surprise AS surprise_intensity,
                            rating_df.other_text AS other_emotion,
                            rating_df.other AS other_intensity,
                            rating_df.pleasure,
                            rating_df.arousal,
                            rating_df.dominance,
                            rating_df.appraisal
                        FROM rating_df 
                        JOIN video_df ON rating_df.video_id = video_df.video_id
                        ORDER BY rating_df.participant_id, rating_df.video_id
                        ''')

# %%
video_rating_df
# Out:
#                 participant_id  video_id    start_time      end_time  \
# 0     5588b2bffdf99b7a7714efd1        22  5/8/24 22:59  5/8/24 23:40
# 1     5588b2bffdf99b7a7714efd1        43  5/8/24 22:59  5/8/24 23:40
# 2     5588b2bffdf99b7a7714efd1        50  5/8/24 22:59  5/8/24 23:40
# 3     5588b2bffdf99b7a7714efd1        84  5/8/24 22:59  5/8/24 23:40
# 4     5588b2bffdf99b7a7714efd1       125  5/8/24 22:59  5/8/24 23:40
# ...                        ...       ...           ...           ...
# 3155  6613a814a0c2d6cb21da8ef8       279  5/8/24 21:33  5/8/24 22:09
# 3156  6613a814a0c2d6cb21da8ef8       387  5/8/24 21:33  5/8/24 22:09
# 3157  6613a814a0c2d6cb21da8ef8       423  5/8/24 21:33  5/8/24 22:09
# 3158  6613a814a0c2d6cb21da8ef8       467  5/8/24 21:33  5/8/24 22:09
# 3159  6613a814a0c2d6cb21da8ef8       478  5/8/24 21:33  5/8/24 22:09
#
#       wander_speed  wander_roundness  wander_roundness_effective  \
# 0        62.775115          0.688911                    0.178370
# 1        61.110970          0.352980                    0.076109
# 2        46.017272          0.530403                    0.154840
# 3        78.659842          0.963506                    0.239340
# 4        74.946312          0.498299                    0.143700
# ...            ...               ...                         ...
# 3155     30.321874          0.203517                    0.034468
# 3156     52.342993          0.496135                    0.213351
# 3157     37.922254          0.283549                    0.150125
# 3158     49.408758          0.420447                    0.087419
# 3159     55.832759          0.652202                    0.245419
#
#       wander_cycle_rate  blink_temperature  blink_slope  ...  fear_intensity  \
# 0              3.862264           0.504496          0.0  ...             NaN
# 1              4.637822           0.929641          0.0  ...             3.0
# 2              3.425497           0.943638          1.0  ...             2.0
# 3              4.025686           0.931626          0.0  ...             3.0
# 4              3.467634           0.330719         -1.0  ...             4.0
# ...                 ...                ...          ...  ...             ...
# 3155           5.904459           0.464465         -1.0  ...             4.0
# 3156           2.325440           0.086675          1.0  ...             2.0
# 3157           1.888757           0.400462          0.0  ...             3.0
# 3158           4.809581           0.447571         -1.0  ...             4.0
# 3159           2.657507           0.231250          0.0  ...             1.0
#
#       anger_intensity  disgust_intensity  surprise_intensity  other_emotion  \
# 0                 1.0                NaN                 NaN        boredom
# 1                 2.0                2.0                 3.0      confusion
# 2                 NaN                NaN                 4.0     curiosity
# 3                 4.0                3.0                 3.0       negative
# 4                 3.0                2.0                 4.0        anxious
# ...               ...                ...                 ...            ...
# 3155              1.0                NaN                 3.0           None
# 3156              1.0                1.0                 2.0           None
# 3157              3.0                1.0                 4.0           None
# 3158              2.0                3.0                 4.0           None
# 3159              4.0                2.0                 2.0           None
#
#       other_intensity  pleasure  arousal  dominance  \
# 0                 5.0         3        3          4
# 1                 4.0         3        5          3
# 2                 5.0         6        7          6
# 3                 4.0         1        5          5
# 4                 4.0         1        7          4
# ...               ...       ...      ...        ...
# 3155              NaN         4        3          3
# 3156              NaN         5        5          5
# 3157              NaN         5        6          4
# 3158              NaN         3        3          1
# 3159              NaN         3        8          8
#
#                                               appraisal
# 0     The robot is slightly bored and grumpy, but is...
# 1     The robot is confused and unsure, but not part...
# 2     The robot is alert and curious about its surro...
# 3     The robot is feeling moderately angry and nega...
# 4     The robot is anxious, worried, and unsure abou...
# ...                                                 ...
# 3155  I believe the robot is in a less cheerful mode...
# 3156  It portrays a feeling of peaceful nature and c...
# 3157  With the sound and lighting and all the robot ...
# 3158              It portrayed a feeling of uncertainty
# 3159            I could imagine the robot as been angry
#
# [3160 rows x 26 columns]

# %%
video_rating_df
# Out:
#                 participant_id  video_id    start_time      end_time  \
# 0     5588b2bffdf99b7a7714efd1        22  5/8/24 22:59  5/8/24 23:40
# 1     5588b2bffdf99b7a7714efd1        43  5/8/24 22:59  5/8/24 23:40
# 2     5588b2bffdf99b7a7714efd1        50  5/8/24 22:59  5/8/24 23:40
# 3     5588b2bffdf99b7a7714efd1        84  5/8/24 22:59  5/8/24 23:40
# 4     5588b2bffdf99b7a7714efd1       125  5/8/24 22:59  5/8/24 23:40
# ...                        ...       ...           ...           ...
# 3155  6613a814a0c2d6cb21da8ef8       279  5/8/24 21:33  5/8/24 22:09
# 3156  6613a814a0c2d6cb21da8ef8       387  5/8/24 21:33  5/8/24 22:09
# 3157  6613a814a0c2d6cb21da8ef8       423  5/8/24 21:33  5/8/24 22:09
# 3158  6613a814a0c2d6cb21da8ef8       467  5/8/24 21:33  5/8/24 22:09
# 3159  6613a814a0c2d6cb21da8ef8       478  5/8/24 21:33  5/8/24 22:09
#
#       wander_speed  wander_roundness  wander_roundness_effective  \
# 0        62.775115          0.688911                    0.178370
# 1        61.110970          0.352980                    0.076109
# 2        46.017272          0.530403                    0.154840
# 3        78.659842          0.963506                    0.239340
# 4        74.946312          0.498299                    0.143700
# ...            ...               ...                         ...
# 3155     30.321874          0.203517                    0.034468
# 3156     52.342993          0.496135                    0.213351
# 3157     37.922254          0.283549                    0.150125
# 3158     49.408758          0.420447                    0.087419
# 3159     55.832759          0.652202                    0.245419
#
#       wander_cycle_rate  blink_temperature  blink_slope  ...  fear_intensity  \
# 0              3.862264           0.504496          0.0  ...             NaN
# 1              4.637822           0.929641          0.0  ...             3.0
# 2              3.425497           0.943638          1.0  ...             2.0
# 3              4.025686           0.931626          0.0  ...             3.0
# 4              3.467634           0.330719         -1.0  ...             4.0
# ...                 ...                ...          ...  ...             ...
# 3155           5.904459           0.464465         -1.0  ...             4.0
# 3156           2.325440           0.086675          1.0  ...             2.0
# 3157           1.888757           0.400462          0.0  ...             3.0
# 3158           4.809581           0.447571         -1.0  ...             4.0
# 3159           2.657507           0.231250          0.0  ...             1.0
#
#       anger_intensity  disgust_intensity  surprise_intensity  other_emotion  \
# 0                 1.0                NaN                 NaN        boredom
# 1                 2.0                2.0                 3.0      confusion
# 2                 NaN                NaN                 4.0     curiosity
# 3                 4.0                3.0                 3.0       negative
# 4                 3.0                2.0                 4.0        anxious
# ...               ...                ...                 ...            ...
# 3155              1.0                NaN                 3.0           None
# 3156              1.0                1.0                 2.0           None
# 3157              3.0                1.0                 4.0           None
# 3158              2.0                3.0                 4.0           None
# 3159              4.0                2.0                 2.0           None
#
#       other_intensity  pleasure  arousal  dominance  \
# 0                 5.0         3        3          4
# 1                 4.0         3        5          3
# 2                 5.0         6        7          6
# 3                 4.0         1        5          5
# 4                 4.0         1        7          4
# ...               ...       ...      ...        ...
# 3155              NaN         4        3          3
# 3156              NaN         5        5          5
# 3157              NaN         5        6          4
# 3158              NaN         3        3          1
# 3159              NaN         3        8          8
#
#                                               appraisal
# 0     The robot is slightly bored and grumpy, but is...
# 1     The robot is confused and unsure, but not part...
# 2     The robot is alert and curious about its surro...
# 3     The robot is feeling moderately angry and nega...
# 4     The robot is anxious, worried, and unsure abou...
# ...                                                 ...
# 3155  I believe the robot is in a less cheerful mode...
# 3156  It portrays a feeling of peaceful nature and c...
# 3157  With the sound and lighting and all the robot ...
# 3158              It portrayed a feeling of uncertainty
# 3159            I could imagine the robot as been angry
#
# [3160 rows x 26 columns]

# %%
# Save the processed data to a new CSV file
video_rating_df.to_csv('../Data/Processed/video_rating.csv', index=False)
