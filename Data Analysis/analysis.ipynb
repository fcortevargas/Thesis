# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'input_data.csv'

# %%
df = pd.read_csv(file_path, header=0, index_col=0)

# %%
df.head(10)
# Out:
#    wanderSpeed  wanderRoundness  wanderCycleRate  blinkTemperature  \
# 0    57.446668         0.520609         2.942600          0.295028
# 1    89.874988         0.370692         4.186486          0.822120
# 2    64.206408         0.925199         0.532234          0.119544
# 3    40.934613         0.216718         5.219168          0.528976
# 4    25.387844         0.831125         3.601540          0.716624
# 5    77.407157         0.060175         2.100177          0.181704
# 6    93.629820         0.739683         5.321722          0.884402
# 7    51.350394         0.402236         1.752312          0.482798
# 8    48.058221         0.988951         5.907546          0.224688
# 9    99.126106         0.150525         1.221544          0.626794
#
#    blinkSlope  blinkCycleRate   beepPitch  beepSlope  beepCycleRate
# 0         1.0        1.041960  647.512386       -0.0       2.247399
# 1        -0.0        3.260959  535.590892        0.0       4.954741
# 2        -1.0        5.393339  950.322404        1.0       3.800995
# 3         0.0        3.131198  161.591571       -1.0       0.664593
# 4         0.0        1.468567  781.300102        1.0       4.141229
# 5        -1.0        4.381811  218.001856       -1.0       1.691700
# 6        -0.0        5.139276  703.492238       -0.0       2.595711
# 7         1.0        2.182890  367.003330        0.0       5.989926
# 8        -0.0        2.812873  860.021799        1.0       4.561652
# 9         1.0        5.701570  298.488259       -1.0       1.252071

# %%
df.describe()
# Out:
#        wanderSpeed  wanderRoundness  wanderCycleRate  blinkTemperature  \
# count   512.000000       512.000000       512.000000        512.000000
# mean     62.500000         0.500000         3.250000          0.500000
# std      21.671809         0.288957         1.589266          0.288957
# min      25.097095         0.001499         0.503279          0.000021
# 25%      43.809711         0.249763         1.877304          0.250857
# 50%      62.532741         0.500169         3.249859          0.499520
# 75%      81.258142         0.750269         4.623030          0.750126
# max      99.984443         0.998101         5.996310          0.998928
#
#        blinkSlope  blinkCycleRate   beepPitch   beepSlope  beepCycleRate
# count  512.000000      512.000000  512.000000  512.000000     512.000000
# mean     0.000000        3.250000  550.000000    0.000000       3.250000
# std      0.707798        1.589266  260.061712    0.707798       1.589266
# min     -1.000000        0.506132  101.413305   -1.000000       0.507215
# 25%     -0.250000        1.874837  325.894388   -0.250000       1.873347
# 50%     -0.000000        3.250453  549.864055    0.000000       3.248513
# 75%      0.250000        4.624470  773.889703    0.250000       4.622843
# max      1.000000        5.994430  998.968634    1.000000       5.989926

# %%
df.cov().round()
# Out:
#                   wanderSpeed  wanderRoundness  wanderCycleRate  \
# wanderSpeed             470.0              0.0              0.0
# wanderRoundness           0.0              0.0             -0.0
# wanderCycleRate           0.0             -0.0              3.0
# blinkTemperature          0.0              0.0             -0.0
# blinkSlope                0.0             -0.0             -0.0
# blinkCycleRate            0.0              0.0              0.0
# beepPitch                -0.0              0.0             -0.0
# beepSlope                 0.0              0.0             -0.0
# beepCycleRate            -0.0              0.0              0.0
#
#                   blinkTemperature  blinkSlope  blinkCycleRate  beepPitch  \
# wanderSpeed                    0.0         0.0             0.0       -0.0
# wanderRoundness                0.0        -0.0             0.0        0.0
# wanderCycleRate               -0.0        -0.0             0.0       -0.0
# blinkTemperature               0.0        -0.0            -0.0       -0.0
# blinkSlope                    -0.0         1.0            -0.0        0.0
# blinkCycleRate                -0.0        -0.0             3.0        0.0
# beepPitch                     -0.0         0.0             0.0    67632.0
# beepSlope                      0.0         0.0            -0.0        0.0
# beepCycleRate                 -0.0         0.0            -0.0       -0.0
#
#                   beepSlope  beepCycleRate
# wanderSpeed             0.0           -0.0
# wanderRoundness         0.0            0.0
# wanderCycleRate        -0.0            0.0
# blinkTemperature        0.0           -0.0
# blinkSlope              0.0            0.0
# blinkCycleRate         -0.0           -0.0
# beepPitch               0.0           -0.0
# beepSlope               1.0            0.0
# beepCycleRate           0.0            3.0

# %%
df.mean()
# Out:
# wanderSpeed          62.50
# wanderRoundness       0.50
# wanderCycleRate       3.25
# blinkTemperature      0.50
# blinkSlope            0.00
# blinkCycleRate        3.25
# beepPitch           550.00
# beepSlope             0.00
# beepCycleRate         3.25
# dtype: float64

# %%
for column in df.columns:
    plt.figure(figsize=(6, 3))
    df[column].hist()
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in df.columns:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
for i in range(len(df.columns)):
    for j in range(i+1, len(df.columns)):
        plt.figure(figsize=(6, 3))
        sns.scatterplot(x=df[df.columns[i]], y=df[df.columns[j]])
        plt.title(f'Scatterplot of {df.columns[i]} vs {df.columns[j]}')
        plt.show()

# %%
corr_matrix = df.corr()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
