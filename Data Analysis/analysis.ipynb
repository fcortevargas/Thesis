# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'data.csv'

# %%
df = pd.read_csv(file_path, header=0, index_col=0)

# %%
df.head()
# Out:
#            wanderSpeed  wanderRoundness  wanderCycleRate  \
# Emotion 1          100              1.0              0.5
# Emotion 2           35              0.5              0.5
# Emotion 3          100              0.0              5.0
# Emotion 4           40              0.0              6.0
#
#            wanderCycleStandardDeviation  blinkTemperature  blinkSlope  \
# Emotion 1                           0.5               0.5           0
# Emotion 2                           0.2               0.0          -1
# Emotion 3                           1.0               1.0           1
# Emotion 4                           0.1               0.3          -1
#
#            blinkCycleRate  blinkTemperatureStandardDeviation  beepPitch  \
# Emotion 1             5.0                               0.40        700
# Emotion 2             0.1                               0.10        100
# Emotion 3             6.0                               0.00        900
# Emotion 4             0.1                               0.05        200
#
#            beepSlope  beepSoundToSilenceRatio  beepCycleRate  \
# Emotion 1          1                      0.8            3.0
# Emotion 2         -1                      0.5            0.5
# Emotion 3          1                      0.9            4.0
# Emotion 4         -1                      0.3            0.2
#
#            beepPitchStandardDeviation  beepRandomSoundProbability
# Emotion 1                         100                         0.4
# Emotion 2                          20                         0.2
# Emotion 3                         100                         0.4
# Emotion 4                          50                         0.1

# %%
df.describe()
# Out:
#        wanderSpeed  wanderRoundness  wanderCycleRate  \
# count     4.000000         4.000000         4.000000
# mean     68.750000         0.375000         3.000000
# std      36.142081         0.478714         2.915476
# min      35.000000         0.000000         0.500000
# 25%      38.750000         0.000000         0.500000
# 50%      70.000000         0.250000         2.750000
# 75%     100.000000         0.625000         5.250000
# max     100.000000         1.000000         6.000000
#
#        wanderCycleStandardDeviation  blinkTemperature  blinkSlope  \
# count                      4.000000          4.000000    4.000000
# mean                       0.450000          0.450000   -0.250000
# std                        0.404145          0.420317    0.957427
# min                        0.100000          0.000000   -1.000000
# 25%                        0.175000          0.225000   -1.000000
# 50%                        0.350000          0.400000   -0.500000
# 75%                        0.625000          0.625000    0.250000
# max                        1.000000          1.000000    1.000000
#
#        blinkCycleRate  blinkTemperatureStandardDeviation   beepPitch  \
# count        4.000000                           4.000000    4.000000
# mean         2.800000                           0.137500  475.000000
# std          3.144307                           0.179699  386.221008
# min          0.100000                           0.000000  100.000000
# 25%          0.100000                           0.037500  175.000000
# 50%          2.550000                           0.075000  450.000000
# 75%          5.250000                           0.175000  750.000000
# max          6.000000                           0.400000  900.000000
#
#        beepSlope  beepSoundToSilenceRatio  beepCycleRate  \
# count   4.000000                 4.000000       4.000000
# mean    0.000000                 0.625000       1.925000
# std     1.154701                 0.275379       1.867931
# min    -1.000000                 0.300000       0.200000
# 25%    -1.000000                 0.450000       0.425000
# 50%     0.000000                 0.650000       1.750000
# 75%     1.000000                 0.825000       3.250000
# max     1.000000                 0.900000       4.000000
#
#        beepPitchStandardDeviation  beepRandomSoundProbability
# count                    4.000000                       4.000
# mean                    67.500000                       0.275
# std                     39.475731                       0.150
# min                     20.000000                       0.100
# 25%                     42.500000                       0.175
# 50%                     75.000000                       0.300
# 75%                    100.000000                       0.400
# max                    100.000000                       0.400

# %%
df.cov()
# Out:
#                                     wanderSpeed  wanderRoundness  \
# wanderSpeed                         1306.250000         4.791667
# wanderRoundness                        4.791667         0.229167
# wanderCycleRate                       -5.833333        -1.250000
# wanderCycleStandardDeviation          12.416667        -0.025000
# blinkTemperature                      12.750000        -0.058333
# blinkSlope                            31.250000        -0.041667
# blinkCycleRate                       112.500000         0.283333
# blinkTemperatureStandardDeviation      2.562500         0.081250
# beepPitch                          13625.000000        12.500000
# beepSlope                             41.666667         0.166667
# beepSoundToSilenceRatio                9.208333         0.037500
# beepCycleRate                         65.375000         0.120833
# beepPitchStandardDeviation          1379.166667         2.916667
# beepRandomSoundProbability             5.125000         0.029167
#
#                                    wanderCycleRate  \
# wanderSpeed                              -5.833333
# wanderRoundness                          -1.250000
# wanderCycleRate                           8.500000
# wanderCycleStandardDeviation              0.183333
# blinkTemperature                          0.550000
# blinkSlope                                0.500000
# blinkCycleRate                           -0.150000
# blinkTemperatureStandardDeviation        -0.366667
# beepPitch                               133.333333
# beepSlope                                -0.333333
# beepSoundToSilenceRatio                  -0.183333
# beepCycleRate                            -0.050000
# beepPitchStandardDeviation               16.666667
# beepRandomSoundProbability               -0.133333
#
#                                    wanderCycleStandardDeviation  \
# wanderSpeed                                           12.416667
# wanderRoundness                                       -0.025000
# wanderCycleRate                                        0.183333
# wanderCycleStandardDeviation                           0.163333
# blinkTemperature                                       0.156667
# blinkSlope                                             0.383333
# blinkCycleRate                                         1.163333
# blinkTemperatureStandardDeviation                     -0.007500
# beepPitch                                            145.000000
# beepSlope                                              0.400000
# beepSoundToSilenceRatio                                0.101667
# beepCycleRate                                          0.718333
# beepPitchStandardDeviation                            12.500000
# beepRandomSoundProbability                             0.051667
#
#                                    blinkTemperature  blinkSlope  \
# wanderSpeed                               12.750000   31.250000
# wanderRoundness                           -0.058333   -0.041667
# wanderCycleRate                            0.550000    0.500000
# wanderCycleStandardDeviation               0.156667    0.383333
# blinkTemperature                           0.176667    0.383333
# blinkSlope                                 0.383333    0.916667
# blinkCycleRate                             1.163333    2.866667
# blinkTemperatureStandardDeviation         -0.010833   -0.004167
# beepPitch                                151.666667  358.333333
# beepSlope                                  0.400000    1.000000
# beepSoundToSilenceRatio                    0.088333    0.241667
# beepCycleRate                              0.698333    1.741667
# beepPitchStandardDeviation                14.500000   32.500000
# beepRandomSoundProbability                 0.045000    0.125000
#
#                                    blinkCycleRate  \
# wanderSpeed                            112.500000
# wanderRoundness                          0.283333
# wanderCycleRate                         -0.150000
# wanderCycleStandardDeviation             1.163333
# blinkTemperature                         1.163333
# blinkSlope                               2.866667
# blinkCycleRate                           9.886667
# blinkTemperatureStandardDeviation        0.158333
# beepPitch                             1203.333333
# beepSlope                                3.600000
# beepSoundToSilenceRatio                  0.826667
# beepCycleRate                            5.836667
# beepPitchStandardDeviation             117.000000
# beepRandomSoundProbability               0.450000
#
#                                    blinkTemperatureStandardDeviation  \
# wanderSpeed                                                 2.562500
# wanderRoundness                                             0.081250
# wanderCycleRate                                            -0.366667
# wanderCycleStandardDeviation                               -0.007500
# blinkTemperature                                           -0.010833
# blinkSlope                                                 -0.004167
# blinkCycleRate                                              0.158333
# blinkTemperatureStandardDeviation                           0.032292
# beepPitch                                                  12.916667
# beepSlope                                                   0.083333
# beepSoundToSilenceRatio                                     0.013750
# beepCycleRate                                               0.067083
# beepPitchStandardDeviation                                  2.458333
# beepRandomSoundProbability                                  0.011250
#
#                                        beepPitch   beepSlope  \
# wanderSpeed                         13625.000000   41.666667
# wanderRoundness                        12.500000    0.166667
# wanderCycleRate                       133.333333   -0.333333
# wanderCycleStandardDeviation          145.000000    0.400000
# blinkTemperature                      151.666667    0.400000
# blinkSlope                            358.333333    1.000000
# blinkCycleRate                       1203.333333    3.600000
# blinkTemperatureStandardDeviation      12.916667    0.083333
# beepPitch                          149166.666667  433.333333
# beepSlope                             433.333333    1.333333
# beepSoundToSilenceRatio                97.500000    0.300000
# beepCycleRate                         710.833333    2.100000
# beepPitchStandardDeviation          14583.333333   43.333333
# beepRandomSoundProbability             52.500000    0.166667
#
#                                    beepSoundToSilenceRatio  beepCycleRate  \
# wanderSpeed                                       9.208333      65.375000
# wanderRoundness                                   0.037500       0.120833
# wanderCycleRate                                  -0.183333      -0.050000
# wanderCycleStandardDeviation                      0.101667       0.718333
# blinkTemperature                                  0.088333       0.698333
# blinkSlope                                        0.241667       1.741667
# blinkCycleRate                                    0.826667       5.836667
# blinkTemperatureStandardDeviation                 0.013750       0.067083
# beepPitch                                        97.500000     710.833333
# beepSlope                                         0.300000       2.100000
# beepSoundToSilenceRatio                           0.075833       0.499167
# beepCycleRate                                     0.499167       3.489167
# beepPitchStandardDeviation                        8.750000      66.750000
# beepRandomSoundProbability                        0.040833       0.267500
#
#                                    beepPitchStandardDeviation  \
# wanderSpeed                                       1379.166667
# wanderRoundness                                      2.916667
# wanderCycleRate                                     16.666667
# wanderCycleStandardDeviation                        12.500000
# blinkTemperature                                    14.500000
# blinkSlope                                          32.500000
# blinkCycleRate                                     117.000000
# blinkTemperatureStandardDeviation                    2.458333
# beepPitch                                        14583.333333
# beepSlope                                           43.333333
# beepSoundToSilenceRatio                              8.750000
# beepCycleRate                                       66.750000
# beepPitchStandardDeviation                        1558.333333
# beepRandomSoundProbability                           4.916667
#
#                                    beepRandomSoundProbability
# wanderSpeed                                          5.125000
# wanderRoundness                                      0.029167
# wanderCycleRate                                     -0.133333
# wanderCycleStandardDeviation                         0.051667
# blinkTemperature                                     0.045000
# blinkSlope                                           0.125000
# blinkCycleRate                                       0.450000
# blinkTemperatureStandardDeviation                    0.011250
# beepPitch                                           52.500000
# beepSlope                                            0.166667
# beepSoundToSilenceRatio                              0.040833
# beepCycleRate                                        0.267500
# beepPitchStandardDeviation                           4.916667
# beepRandomSoundProbability                           0.022500

# %%
for column in df.columns:
    plt.figure(figsize=(8, 4))
    df[column].hist()
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in df.columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
for i in range(len(df.columns)):
    for j in range(i+1, len(df.columns)):
        plt.figure(figsize=(8, 4))
        sns.scatterplot(x=df[df.columns[i]], y=df[df.columns[j]])
        plt.title(f'Scatterplot of {df.columns[i]} vs {df.columns[j]}')
        plt.show()

# %%
corr_matrix = df.corr()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
