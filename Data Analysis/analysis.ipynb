# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'data.csv'

# %%
df = pd.read_csv(file_path, header=0, index_col=0)

# %%
df.head()
# Out:
#            wanderSpeed  wanderRoundness  wanderCycleRate  blinkTemperature  \
# Emotion 1          100              1.0              0.5               0.7
# Emotion 2           35              0.5              0.5               0.0
# Emotion 3          100              0.0              5.0               1.0
# Emotion 4           40              0.0              6.0               0.3
#
#            blinkSlope  blinkCycleRate  beepPitch  beepSlope  beepCycleRate
# Emotion 1           0             5.0        700          1            3.0
# Emotion 2          -1             0.1        100         -1            0.5
# Emotion 3           1             6.0        900          1            4.0
# Emotion 4          -1             0.1        200         -1            0.2

# %%
df.describe()
# Out:
#        wanderSpeed  wanderRoundness  wanderCycleRate  blinkTemperature  \
# count     4.000000         4.000000         4.000000          4.000000
# mean     68.750000         0.375000         3.000000          0.500000
# std      36.142081         0.478714         2.915476          0.439697
# min      35.000000         0.000000         0.500000          0.000000
# 25%      38.750000         0.000000         0.500000          0.225000
# 50%      70.000000         0.250000         2.750000          0.500000
# 75%     100.000000         0.625000         5.250000          0.775000
# max     100.000000         1.000000         6.000000          1.000000
#
#        blinkSlope  blinkCycleRate   beepPitch  beepSlope  beepCycleRate
# count    4.000000        4.000000    4.000000   4.000000       4.000000
# mean    -0.250000        2.800000  475.000000   0.000000       1.925000
# std      0.957427        3.144307  386.221008   1.154701       1.867931
# min     -1.000000        0.100000  100.000000  -1.000000       0.200000
# 25%     -1.000000        0.100000  175.000000  -1.000000       0.425000
# 50%     -0.500000        2.550000  450.000000   0.000000       1.750000
# 75%      0.250000        5.250000  750.000000   1.000000       3.250000
# max      1.000000        6.000000  900.000000   1.000000       4.000000

# %%
df.cov()
# Out:
#                    wanderSpeed  wanderRoundness  wanderCycleRate  \
# wanderSpeed        1306.250000         4.791667        -5.833333
# wanderRoundness       4.791667         0.229167        -1.250000
# wanderCycleRate      -5.833333        -1.250000         8.500000
# blinkTemperature     14.833333        -0.016667         0.383333
# blinkSlope           31.250000        -0.041667         0.500000
# blinkCycleRate      112.500000         0.283333        -0.150000
# beepPitch         13625.000000        12.500000       133.333333
# beepSlope            41.666667         0.166667        -0.333333
# beepCycleRate        65.375000         0.120833        -0.050000
#
#                   blinkTemperature  blinkSlope  blinkCycleRate      beepPitch  \
# wanderSpeed              14.833333   31.250000      112.500000   13625.000000
# wanderRoundness          -0.016667   -0.041667        0.283333      12.500000
# wanderCycleRate           0.383333    0.500000       -0.150000     133.333333
# blinkTemperature          0.193333    0.400000        1.310000     166.666667
# blinkSlope                0.400000    0.916667        2.866667     358.333333
# blinkCycleRate            1.310000    2.866667        9.886667    1203.333333
# beepPitch               166.666667  358.333333     1203.333333  149166.666667
# beepSlope                 0.466667    1.000000        3.600000     433.333333
# beepCycleRate             0.770000    1.741667        5.836667     710.833333
#
#                    beepSlope  beepCycleRate
# wanderSpeed        41.666667      65.375000
# wanderRoundness     0.166667       0.120833
# wanderCycleRate    -0.333333      -0.050000
# blinkTemperature    0.466667       0.770000
# blinkSlope          1.000000       1.741667
# blinkCycleRate      3.600000       5.836667
# beepPitch         433.333333     710.833333
# beepSlope           1.333333       2.100000
# beepCycleRate       2.100000       3.489167

# %%
for column in df.columns:
    plt.figure(figsize=(8, 4))
    df[column].hist()
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for column in df.columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
for i in range(len(df.columns)):
    for j in range(i+1, len(df.columns)):
        plt.figure(figsize=(8, 4))
        sns.scatterplot(x=df[df.columns[i]], y=df[df.columns[j]])
        plt.title(f'Scatterplot of {df.columns[i]} vs {df.columns[j]}')
        plt.show()

# %%
corr_matrix = df.corr()

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
